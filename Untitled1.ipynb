# %%
import pandas as pd
import numpy as np

# %%
# Doc du lieu vao DF
my_df=pd.read_csv("students.csv")

# %%
# ghi du lieu vao file
my_df.to_csv("newstudents.csv")

# %%
#xem thong tin dataframe
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      768 non-null    int64
#  1   A2      768 non-null    int64
#  2   A3      768 non-null    int64
#  3   A4      768 non-null    int64
#  4   A5      768 non-null    int64
#  5   A6      768 non-null    float64
#  6   A7      768 non-null    float64
#  7   A8      768 non-null    int64
#  8   A9      768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#lay theo 1 hoac nhieu cot
my_df[['A3','A7']]

# %%
#lay 10 dong dau tien
my_df.head(10)

# %%
#lay 20 dong cuoi cung
my_df.tail(20)

# %%
#lay tu dong nao toi dong nao
my_df[0:15]

# %%
#lay theo dieu kien 
my_df[my_df.A9==1]

# %%
#lay theo dieu kien
my_td=my_df[(my_df['A5']>100)&(my_df['A9']==1)]

# %%
my_td.to_csv("my_td.csv")

# %%
#them 1 cot data nhan doi chi so =A9*2
my_df['DoubleA9']=my_df['A9']*3

# %%
my_df

# %%
#them 1 cot pass neu A5 >100 thi pass else pass=0
my_df['pass']= np.where(my_df['A5']>100,1,0)
#in my_df
my_df

# %%
#xoa cot
#my_df.drop(columns=['pass'],inplace=True)
my_df

# %%
#xoa hang 234
my_df.drop(index=[2,3,4])
my_df

# %%
my_df.sort_values(by=['A5'], ascending=False)

# %%
my_df.describe()

# %%
#ve bieu do
my_df['A3'].plot.line(color='red', linestyle='--')

# %%
my_df['A5'].plot.bar(color='red', linestyle='-')

# %%
my_df['A9'].plot.pie()

# %%
group_df= my_df[['A9','A8']]
group_df
# Out:
#      A9  A8
# 0     1  50
# 1     0  31
# 2     1  32
# 3     0  21
# 4     1  33
# ..   ..  ..
# 763   0  63
# 764   0  27
# 765   0  30
# 766   1  47
# 767   0  23
#
# [768 rows x 2 columns]

# %%
group_df= group_df.groupby('A9').size()
group_df
# Out:
# A9
# 0    500
# 1    268
# dtype: int64

# %%
#Group lai va ve bieu do
group_df.plot.pie(subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a708c5e90>],
#       dtype=object)

# %%
#kiem tra kieu du lieu
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   A1        768 non-null    int64
#  1   A2        768 non-null    int64
#  2   A3        768 non-null    int64
#  3   A4        768 non-null    int64
#  4   A5        768 non-null    int64
#  5   A6        768 non-null    float64
#  6   A7        768 non-null    float64
#  7   A8        768 non-null    int64
#  8   A9        768 non-null    int64
#  9   DoubleA9  768 non-null    int64
# dtypes: float64(2), int64(8)
# memory usage: 60.1 KB
